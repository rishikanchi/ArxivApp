# %%
# !pip install pymongo
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.
# ...
#      -------------------------------------- 484.1/484.1 kB 1.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 307.7/307.7 kB 1.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pymongo
import scipy.cluster.hierarchy as hcluster
import numpy as np
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from math import pi

# %%
df = pd.read_csv("arxiv_100k.csv")

myclient = pymongo.MongoClient("mongodb+srv://rishirkanchi:QxeAnSvizBC6VC1R@cluster0.cf3bg.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
mydb = myclient["ArxivData"]
mycol = mydb["embeddings"]

# %%
data_conv = {
    "astro-ph" : "Astrophysics",
    "cond-mat" : "Condensed Material",
    "cs" : "Computer Science",
    "econ" : "Economics",
    "eess" : "Electrical Engineering and Systems Science",
    "gr-qc" : "General Relativity and Quantum Cosmology",
    "hep-ex" : "High Energy Physics - Experiment",
    "hep-lat" : "High Energy Physics - Lattice",
    "hep-ph" : "High Energy Physics - Phenomenology",
    "hep-th" : "High Energy Physics - Theory",
    "math" : "Mathematics",
    "math-ph" : "Mathematical Physics",
    "nlin" : "Nonlinear Sciences",
    "nucl-ex" : "Nuclear Experiment",
    "nucl-th" : "Nuclear Theory",
    "physics" : "Physics",
    "q-bio" : "Quantitative Biology",
    "q-fin" : "Quantitative Finance",
    "quant-ph" : "Quantum Physics",
    "stat" : "Statistics"
}

df["label"] = df["categories"].apply(lambda x: x.split()[0].split(".")[0]).map(data_conv)

# %%
unique_tags = df["label"].unique()

data = []

for tag in unique_tags:
    print(tag)
    df_subset = df[df["label"] == tag]

    

    cluster_algorithm = AgglomerativeClustering(distance_threshold=200, n_clusters=None)

    cluster_algorithm.fit(df_subset[["Dim1", "Dim2"]].values)

    clusters = cluster_algorithm.labels_

    unique, counts = np.unique(clusters, return_counts=True)

    df_subset["cluster"] = clusters


    plt.figure(figsize=(20, 10))

    plt.scatter(df_subset["Dim1"], df_subset["Dim2"], c=df_subset["cluster"])

    for cluster in unique:
        idxs = np.where(clusters==cluster)[0]
        df_subset_subset = df_subset.iloc[idxs]
        central_point = np.array([df_subset_subset["Dim1"].mean(), df_subset_subset["Dim2"].mean()])

        x_q1 = df_subset_subset['Dim1'].quantile(0.2)
        x_q3 = df_subset_subset['Dim1'].quantile(0.8)

        # Calculate the quartiles for the y coordinates
        y_q1 = df_subset_subset['Dim2'].quantile(0.2)
        y_q3 = df_subset_subset['Dim2'].quantile(0.8)

        # Filter the DataFrame to include only the rows where x and y are within the second and third quartiles
        filtered_df = df_subset_subset[(df_subset_subset['Dim1'] >= x_q1) & (df_subset_subset['Dim1'] <= x_q3) & (df_subset_subset['Dim2'] >= y_q1) & (df_subset_subset['Dim2'] <= y_q3)]

        max_x = -1
        max_y = -1

        for row in filtered_df.iterrows():
            row = row[1]
            max_x = max(max_x, abs(row["Dim1"] - central_point[0]))
            max_y = max(max_y, abs(row["Dim2"] - central_point[1]))

        data.append({
            "x" : filtered_df["Dim1"].mean(),
            "y" : filtered_df["Dim2"].mean(),
            "cluster_name" : f"{tag}_{cluster}",
            "radius_x" : max_x,
            "radius_y" : max_y,
        })

        u=data[-1]["x"]     #x-position of the center
        v=data[-1]["y"]    #y-position of the center
        a=data[-1]["radius_x"]     #radius on the x-axis
        b=data[-1]["radius_y"]

        t = np.linspace(0, 2*pi, 100)
        plt.plot( u+a*np.cos(t) , v+b*np.sin(t) )
        plt.grid(color='lightgray',linestyle='--')
        
    
    plt.show()
# Out:
# High Energy Physics - Phenomenology
# <ipython-input-51-9ed16ebdaf89>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset["cluster"] = clusters
# Mathematics
# <ipython-input-51-9ed16ebdaf89>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset["cluster"] = clusters
# Physics
# <ipython-input-51-9ed16ebdaf89>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
mycol.insert_many(data)
# Out:
# InsertManyResult([ObjectId('6678ba1c5d4b5a76d7735f08'), ObjectId('6678ba1c5d4b5a76d7735f09'), ObjectId('6678ba1c5d4b5a76d7735f0a'), ObjectId('6678ba1c5d4b5a76d7735f0b'), ObjectId('6678ba1c5d4b5a76d7735f0c'), ObjectId('6678ba1c5d4b5a76d7735f0d'), ObjectId('6678ba1c5d4b5a76d7735f0e'), ObjectId('6678ba1c5d4b5a76d7735f0f'), ObjectId('6678ba1c5d4b5a76d7735f10'), ObjectId('6678ba1c5d4b5a76d7735f11'), ObjectId('6678ba1c5d4b5a76d7735f12'), ObjectId('6678ba1c5d4b5a76d7735f13'), ObjectId('6678ba1c5d4b5a76d7735f14'), ObjectId('6678ba1c5d4b5a76d7735f15'), ObjectId('6678ba1c5d4b5a76d7735f16'), ObjectId('6678ba1c5d4b5a76d7735f17'), ObjectId('6678ba1c5d4b5a76d7735f18'), ObjectId('6678ba1c5d4b5a76d7735f19'), ObjectId('6678ba1c5d4b5a76d7735f1a'), ObjectId('6678ba1c5d4b5a76d7735f1b'), ObjectId('6678ba1c5d4b5a76d7735f1c'), ObjectId('6678ba1c5d4b5a76d7735f1d'), ObjectId('6678ba1c5d4b5a76d7735f1e')], acknowledged=True)
